# %%
import pybamm
print(pybamm.IDAKLUSolver().available)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pybamm
# ----> 2 print(pybamm.IDAKLUSolver().available)
#
# File ~/PyBaMM/pybamm/solvers/idaklu_solver.py:118, in IDAKLUSolver.__init__(self, rtol, atol, root_method, root_tol, extrap_tol, output_variables, options)
#     115 self.output_variables = [] if output_variables is None else output_variables
#     117 if idaklu_spec is None:  # pragma: no cover
# --> 118     raise ImportError("KLU is not installed")
#     120 super().__init__(
#     121     "ida",
#     122     rtol,
#    (...)
#     127     output_variables,
#     128 )
#     129 self.name = "IDA KLU solver"
#
# ImportError: KLU is not installed
